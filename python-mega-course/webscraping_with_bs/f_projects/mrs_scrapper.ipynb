# %%
import requests
from bs4 import BeautifulSoup

# %%
data1={
    "ID":"UHJvamVjdElEPTkmRGl2aXNpb249NSZVc2VySUQ9ODQ3JlJvbGVJRD0xJkFwcElEPTczMDkyJkFjdGlvbj1TRUFSQ0gmQ2hhcmFjdGVyRD0xMSZFeHRBcHBJRD0="
}

# %%
url1 = "https://maharerait.mahaonline.gov.in/SearchList/ShowCertificate"
response = requests.post(url1, data=data1)
doc = BeautifulSoup(response.content, 'html.parser')
print(doc.prettify)
# Out:
# <bound method Tag.prettify of ...>

# %%
data={   
"__RequestVerificationToken": "zBn9eHJuR3tfsAXytw0D9hSYSzA1PJ5d0m7Qn_7z0ng_e23GWtoQPLSY9emRZzcgEVpBRRgp_SIi82PNm0QIlUVZ-SmVEu0I6VxDa2dkNU01",
"ID": 0,
"pageTraverse": 1,
"Project":"" ,
"hdnProject":"", 
"Promoter": "",
"hdnPromoter":"", 
"AgentName": "",
"hdnAgent": "",
"CertiNo": "",
"hdnCertiNo":"", 
"State": 27,
"Division": 5,
"hdnDivision":"", 
"hdnDistrict": "",
"hdnProject": "",
"hdnDTaluka": "",
"hdnVillage": "",
"hdnState": "",
"District": "",
"Taluka": "",
"Village": "",
"CompletionDate_From":"", 
"hdnfromdate": "",
"CompletionDate_To":"", 
"hdntodate": "",
"PType": "",
"hdnPType":"", 
"btnSearch": "Search"
      }

url = "https://maharerait.mahaonline.gov.in/SearchList/Search"
response = requests.post(url, data=data)
doc = BeautifulSoup(response.content, 'html.parser')
#print(doc)

# %%
try:

    sr=doc.find("div",{"id":"DivBind"})
    if sr.find("label").get_text().strip()=="No Records Found":
        print("No Records Found")
    else:
        print("SEARCH RESULT")
        static_url="https://maharerait.mahaonline.gov.in"
        urls=[]
        #sr=doc.find("div",{"id":"DivBind"})
        tbody=sr.find("table").find("tbody")

        for row  in tbody.find_all("tr"):
            url=row.find_all("td")[4].find("a")['href']
            url=static_url+url
            urls.append(url)
except:
        print("Something went wrong.......")
# Out:
# SEARCH RESULT

# %%
len(urls)
# Out:
# 50

# %%
__RequestVerificationToken: -xiy9Jc2lbte6mW_lMb4Hg6hvuZ5IWKc_Yf_RokaUcuTphpKFTYmqcrST_lvaeMF2DwVUelEOUQ36Jny3N7KQdtFK0hTKD60IsoC8-1lJ8E1

# %%
       
data={   
"__RequestVerificationToken": "-xiy9Jc2lbte6mW_lMb4Hg6hvuZ5IWKc_Yf_RokaUcuTphpKFTYmqcrST_lvaeMF2DwVUelEOUQ36Jny3N7KQdtFK0hTKD60IsoC8-1lJ8E1",
"Type":"Promoter",
"ID": 0,
"pageTraverse": 1,
"Project":"" ,
"hdnProject":"", 
"Promoter": "",
"hdnPromoter":"", 
"AgentName": "",
"hdnAgent": "",
"CertiNo": "",
"hdnCertiNo":"", 
"State": 27,
"Division": 5,
"hdnDivision":"", 
"hdnDistrict": "",
"hdnProject": "",
"hdnDTaluka": "",
"hdnVillage": "",
"hdnState": 27,
"District": "",
"Taluka": "",
"Village": "",
"CompletionDate_From":"", 
"hdnfromdate": "",
"CompletionDate_To":"", 
"hdntodate": "",
"PType": "",
"hdnPType":"",
"TotalRecords": 6432,
"CurrentPage": 2,
"TotalPages": 129,
"Command": "Next"
}
url = "https://maharerait.mahaonline.gov.in/SearchList/Search"
response = requests.post(url, data=data)
doc = BeautifulSoup(response.content, 'html.parser')

# %%
print(doc.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!--[if IE]>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <meta http-equiv="cache-control" content="no-cache, no store" />
#         <meta http-equiv="cache-control" content="private" />
#         <meta http-equiv="cache-control" content="must-revalidate" />
#         <meta http-equiv="cache-control" content="post-check=0" />
#         <meta http-equiv="cache-control" content="pre-check=0" />
#         <meta http-equiv="pragma" content="no-cache" />
#      <![endif]-->
# <meta charset="utf-8"/>
# <meta content="IE=10" http-equiv="X-UA-Compatible"/>
# <title>Login Page : Maharashtra Real Estate Regulatory Authority</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="no-cache, no store" http-equiv="cache-control"/>
# <meta content="private" http-equiv="cache-control"/>
# <meta content="must-revalidate" http-equiv="cache-control"/>
# <meta content="post-check=0" http-equiv="cache-control"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" id="viewport" name="viewport"/>
# <meta content="pre-check=0" http-equiv="cache-control">
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link href="../../Content/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="../../Content/Login.css" rel="stylesheet" type="text/css"/>
# <link href="../../Content/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="../../Content/animate.min.css" rel="stylesheet" type="text/css"/>
# <link href="../../Content/msgBoxLight.css" rel="stylesheet" type="text/css"/>
# <link href="../../Scripts/sweetalert2.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/demo.css" rel="stylesheet"/>
# <link href="/Content/normalize.css" rel="stylesheet"/>
# <link href="/Content/set1.css" rel="stylesheet"/>
# <script src="../../Scripts/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/Scripts/bootstrap.min.js"></script>
# <!--[if IE]>
#         <script src="../../Scripts/respond.min.js" type="text/javascript"></script>
#         <script type="text/javascript" src="../../Scripts/html5shiv.js"></script>
#     <![endif]-->
# <script src="../../Scripts/jquery.slimscroll.js" type="text/javascript"></script>
# <script src="../../Scripts/custom.js" type="text/javascript"></script>
# <script src="../../Scripts/ValidationScripts.js" type="text/javascript"></script>
# <script src="../../Scripts/md5.js" type="text/javascript"></script>
# <script src="../../Scripts/sweet-alert2.min.js" type="text/javascript"></script>
# <script src="/Scripts/classie.js"></script>
# <script src="../../Scripts/jquery.validate.min.js" type="text/javascript"></script>
# <script src="../../Scripts/jquery.validate.unobtrusive.js" type="text/javascript"></script>
# </meta></head>
# <body>
# <noscript>
# <meta content="0;URL=../ShowErrorPage.html" http-equiv="Refresh"/>
# </noscript>
# <section>
# <div class="login-bg">
# <div class="container">
# <link href="/Content/jquery-ui.css" rel="stylesheet"/>
# <script src="/Scripts/jquery.validate.min.js" type="text/javascript"></script>
# <script src="/Scripts/jquery.validate.unobtrusive.min.js" type="text/javascript"></script>
# <script src="/Scripts/sweet-alert2.min.js"></script>
# <link href="/Scripts/sweetalert2.css" rel="stylesheet"/>
# <script src="/Scripts/jquery-1.7.1.min.js"></script>
# <link href="/Content/jquery-ui.css" rel="stylesheet"/>
# <script src="/Scripts/jquery-ui-1.10.0.min.js"></script>
# <script src="/Scripts/jquery-1.11.1.min.js"></script>
# <script src="/Scripts/jquery-ui-1.11.1.min.js"></script>
# <link href="/Scripts/jquery-ui-1.11.1.css" rel="stylesheet"/>
# <style>
#     .loader {
#         position: absolute;
#         top: 0px;
#         right: 0px;
#         width: 100%;
#         height: 100%;
#         z-index: 9999;
#         background: url('../../Images/loading.gif') 50% 50% no-repeat rgb(249,249,249);
#         opacity: .8;
#     }
# </style>
# <script type="text/javascript">
#     $(window).load(function () {
#         $(".loader").fadeOut("slow");
#     });
#
#     $(document).ready(function () {
#     var type= "Promoter";
#
#         if(type=="Promoter")
#         {
#             $("#divAgentName").hide();
#             $("#divProject").show();
#             $("#divPromoName").show();
#             $("#divAdvanceSearchbtn").show();
#             $("#divCerti").show();
#             $("#divHideAdvanceSearchbtn").hide();
#
#
#
#             debugger;
#             var division = $("#hdnDivision").attr("value");
#             var dist = $("#hdnDistrict").attr("value");
#             var proj = $("#hdnProject").attr("value");
#             var taluka = $("#hdnTaluka").attr("value");
#             var village = $("#hdnVillage").attr("value");
#             var pro_name = $("#hdnProject").attr("value");
#             var promoter_name = $("#hdnPromoter").attr("value");
#             var cert_no = $("#hdnCertiNo").attr("value");
#             var from_date = $("#hdnfromdate").attr("value");
#             var to_date = $("#hdntodate").attr("value");
#             var pro_type = $("#hdnPType").attr("value");
#             var state = $("#hdnState").attr("value");
#
#             if((division!=undefined && division!='') || (dist!=undefined && dist!='') || (taluka!=undefined && taluka!='') || (village!=undefined && village!='') || (from_date!=undefined && from_date!='')|| (to_date!=undefined && to_date!='') || (pro_type!=undefined && pro_type!='') ||  (state!=undefined && state!=''))
#             {
#                 $("#divTalVill").show();
#                 $("#divDivision").show();
#                 $("#divDistrict").show();
#                 $("#divFromDate").show();
#                 $("#divToDate").show();
#                 $("#divProjectType").show();
#                 $("#divHideAdvanceSearchbtn").show();
#                 $("#divAdvanceSearchbtn").hide();
#                 $("#divState").show();
#                 $("#divAgentName").hide();
#             }
#             else
#             {
#
#                 $("#divTalVill").hide();
#                 $("#divDivision").hide();
#                 $("#divDistrict").hide();
#                 $("#divFromDate").hide();
#                 $("#divToDate").hide();
#                 $("#divProjectType").hide();
#                 $("#divAdvanceSearchbtn").show();
#                 $("#divHideAdvanceSearchbtn").hide();
#                 $("#divState").hide();
#
#                 $("#PromoterName").hide();
#             }
#             if(state!=undefined && state!='')
#             {
#
#                 if(division!=undefined && division!='')
#                 {
#                     InnerDivision(state,'Division',division);
#
#                     if(dist != undefined && dist != '')
#                     {
#                         InnerDistrict(division,'District',dist);
#                         //DistrictList('Division','District',dist);
#                         if(proj != undefined && proj != '')
#                         {
#                             var DivID = $("#Division").val();
#                             var DisID = dist; //$("#" + ID).val();
#                             ProjectName(DivID, DisID, 'Project', proj);
#                         }
#                         if(taluka!=undefined && taluka!='')
#                         {
#                             InnerTaluka(dist, "Taluka", taluka);
#                             if(village!=undefined && village!='')
#                             {
#                                 InnerVillage(taluka, 'Village',village);
#                             }else{
#                                 InnerVillage(taluka, 'Village',0);
#                             }
#                         }else{
#                             InnerTaluka(dist, "Taluka", 0);
#                         }
#
#                     }
#                     else{
#                         InnerDistrict(division,'District',0);
#                     }
#                     //if(taluka!=undefined && taluka!='')
#                     //{
#                     //    InnerTaluka(dist, "Taluka", taluka);
#                     //}
#                     //if(village!=undefined && village!='')
#                     //{
#                     //    InnerVillage(taluka, 'Village',village);
#                     //}
#                 }
#                 else{
#                     InnerDivision(state,'Division',0);
#                 }
#             }
#
#         }
#         else
#         {
#
#             $("#divAgentName").hide();
#             $("#divProject").show();
#             $("#divPromoName").show();
#             //$("#divSourceComplaintNo").hide();
#             //$("#divSourceComplaintName").hide();
#
#             $("#divTalVill").hide();
#             $("#divCerti").show();
#             $("#divDistrict").hide();
#             $("#divFromDate").hide();
#             $("#divToDate").hide();
#             $("#divDivision").hide();
#             $("#divAdvanceSearchbtn").hide();
#             $("#divHideAdvanceSearchbtn").hide();
#             $("#divProjectType").hide();
#             $("#divState").hide();
#
#
#             var division = $("#hdnDivision").attr("value");
#             var dist = $("#hdnDistrict").attr("value");
#             var proj = $("#hdnProject").attr("value");
#             var taluka = $("#hdnTaluka").attr("value");
#             var village = $("#hdnVillage").attr("value");
#             var pro_name = $("#hdnProject").attr("value");
#             var promoter_name = $("#hdnPromoter").attr("value");
#             var cert_no = $("#hdnCertiNo").attr("value");
#             var from_date = $("#hdnfromdate").attr("value");
#             var to_date = $("#hdntodate").attr("value");
#             var pro_type = $("#hdnPType").attr("value");
#             var state = $("#hdnState").attr("value");
#
#
#             if((division!=undefined && division!='') || (dist!=undefined && dist!='') || (taluka!=undefined && taluka!='') || (village!=undefined && village!='') || (state!=undefined && state!=''))
#             {
#                 $("#divTalVill").show();
#                 $("#divDivision").show();
#                 $("#divDistrict").show();
#                 //$("#divFromDate").show();
#                 //$("#divToDate").show();
#                 //$("#divProjectType").show();
#                 $("#divHideAdvanceSearchbtn").show();
#                 $("#divAdvanceSearchbtn").hide();
#                 $("#divState").show();
#                 //$("#divAgentName").hide();
#             }
#             else
#             {
#
#                 $("#divTalVill").hide();
#                 $("#divDivision").hide();
#                 $("#divDistrict").hide();
#                 $("#divFromDate").hide();
#                 $("#divToDate").hide();
#                 $("#divProjectType").hide();
#                 $("#divAdvanceSearchbtn").show();
#                 $("#divHideAdvanceSearchbtn").hide();
#                 $("#divState").hide();
#
#                 $("#PromoterName").hide();
#             }
#
#
#
#             //if(type == "Promoter" && $('#divHideAdvanceSearchbtn').prop('disabled'))
#             //if(type == "Promoter")
#             //{
#             //    $("#divAgentName").hide();
#             //    $("#divTalVill").hide();
#             //    $("#divCerti").show();
#             //    $("#divDistrict").hide();
#             //    $("#divFromDate").hide();
#             //    $("#divToDate").hide();
#             //    $("#divDivision").hide();
#             //    $("#divAdvanceSearchbtn").hide();
#             //    $("#divHideAdvanceSearchbtn").hide();
#             //    $("#divProjectType").hide();
#             //    $("#divState").hide();
#
#             //}
#
#             //&& $('#divAdvanceSearchbtn:visible').length == 0
#
#             if(type == "Agent" )
#             {
#                 $("#divAgentName").show();
#                 $("#divProject").hide();
#                 $("#divPromoName").hide();
#                 $("#promoter_name").val("");
#                 $("#AgentName").val("");
#
#             }
#
#             // $('#')
#
#            if(state!=undefined && state!='')
#             {
#
#                 if(division!=undefined && division!='')
#                 {
#                     InnerDivision(state,'Division',division);
#
#                     if(dist != undefined && dist != '')
#                     {
#                         InnerDistrict(division,'District',dist);
#                         //DistrictList('Division','District',dist);
#                         if(proj != undefined && proj != '')
#                         {
#                             var DivID = $("#Division").val();
#                             var DisID = dist; //$("#" + ID).val();
#                             ProjectName(DivID, DisID, 'Project', proj);
#                         }
#                         if(taluka!=undefined && taluka!='')
#                         {
#                             InnerTaluka(dist, "Taluka", taluka);
#                             if(village!=undefined && village!='')
#                             {
#                                 InnerVillage(taluka, 'Village',village);
#                             }else{
#                                 InnerVillage(taluka, 'Village',0);
#                             }
#                         }else{
#                             InnerTaluka(dist, "Taluka", 0);
#                         }
#
#                     }
#                     else{
#                         InnerDistrict(division,'District',0);
#                     }
#                     //if(taluka!=undefined && taluka!='')
#                     //{
#                     //    InnerTaluka(dist, "Taluka", taluka);
#                     //}
#                     //if(village!=undefined && village!='')
#                     //{
#                     //    InnerVillage(taluka, 'Village',village);
#                     //}
#                 }
#                 else{
#                     InnerDivision(state,'Division',0);
#                 }
#             }
# }
#
#         $('#btnCancel').click(function (e)
#         {
#             location.href = '/Login/Login/';
#         });
#
#         $('#btnReset').click(function (e)
#         {
#             location.href = '/SearchList/Search';
#         });
#
#         function fnValidateOnSearch()
#         {
#
#             var flag = true;
#             var text = "Please enter \n";
#             $("#pageTraverse").val('1');
#             var value = $('#Promoter').val();
#             if($('#Promoter').is(':checked')){
#
#                 if($('#divDivision:visible').length == 0)
#                 {
#                     if($("#Project").val()=="" && $("#promoter_name").val()=="" && $("#CertiNo").val()=="")
#                     {
#                         flag = false;
#                         text = text + "atleast one of search item.\n";
#                     }
#                 }
#                 else if($('#divDivision:visible').length == 1)
#                 {
#                     if($("#Project").val()=="" && $("#promoter_name").val()=="" && $("#CertiNo").val()=="" && $("#CompletionDate_From").val()=="" &&  $("#CompletionDate_To").val()=="" && $("#Division").val()=="" && $("#District").val()=="" && $("#Taluka").val()=="" && $("#Village").val()=="" && $("#PType").val()=="" && $("#State").val()=="")
#                     {
#                         flag = false;
#                         text = text + "atleast one of search item.\n";
#                     }
#                 }
#             }
#
#             if($('#Agent').is(':checked'))
#             {
#                 if($("#Agent_name").val()!="" && $("#Agent_name").val().length < 4)
#                 {
#                     flag = false;
#                     text = text + "atleast 4 characters in Agent name\n";
#                 }
#
#                 if($('#divDivision:visible').length == 0)
#                 {
#                     if($("#Agent_name").val()=="" && $("#CertiNo").val()=="")
#                     {
#                         flag = false;
#                         text = text + "atleast one of search item.\n";
#                     }
#                 }
#                 else if($('#divDivision:visible').length == 1)
#                 {
#                     if($("#Agent_name").val()=="" && $("#CertiNo").val()=="" && $("#Division").val()=="" && $("#District").val()=="" && $("#Taluka").val()=="" && $("#Village").val()=="" &&  $("#State").val()=="")
#                     {
#                         flag = false;
#                         text = text + "atleast one of search item.\n";
#                     }
#
#                     //if($("#Agent_name").val()=="" && $("#promoter_name").val()=="" && $("#CertiNo").val()=="" && $("#CompletionDate_From").val()=="" &&  $("#CompletionDate_To").val()=="" && $("#Division").val()=="" && $("#District").val()=="" && $("#Taluka").val()=="" && $("#Village").val()=="" && $("#PType").val()=="" && $("#State").val()=="")
#                     //{
#                     //    flag = false;
#                     //    text = text + "atleast one of search item.\n";
#                     //}
#                 }
#             }
#
#             if($("#CompletionDate_From").val()!="" && $("#CompletionDate_To").val()=="")
#             {
#                 flag = false;
#                 text = text + " Proposed completion To Date also\n";
#             }
#             if($("#CompletionDate_From").val()=="" && $("#CompletionDate_To").val()!="")
#             {
#                 flag = false;
#                 text = text + " Proposed completion From Date also\n";
#             }
#
#             if($("#Project").val()!="" && $("#Project").val().length < 4)
#             {
#                 flag = false;
#                 text = text + "atleast 4 characters in project name\n";
#             }
#             if($("#promoter_name").val()!="" && $("#promoter_name").val().length < 4)
#             {
#                 flag = false;
#                 text = text + "atleast 4 characters in promoter name\n";
#             }
#
#             if($("#Agent").val()!="" && $("#Agent").val().length < 4)
#             {
#                 flag = false;
#                 text = text + "atleast 4 characters in Agent name\n";
#             }
#
#             if($("#CertiNo").val()!="" && $("#CertiNo").val().length < 4)
#             {
#                 flag = false;
#                 text = text + " atleast 4 characters in certificate no\n";
#             }
#             if(!flag){
#                 alert(text);
#             }
#             return flag;
#         }
#
#         $("#btnSearch").on("click", function () {
#            debugger;
#
#            if(fnValidateOnSearch())
#            {
#                return true;
#            }
#            else
#            {
#                return false;
#            }
#         });
#
#         $('#btnFirst').click(function () {
#             if(fnValidateOnSearch())
#             {
#                 return true;
#             }
#             else
#             {
#                 return false;
#             }
#         });
#
#         $('#btnPrevious').click(function () {
#             if(fnValidateOnSearch())
#             {
#                 return true;
#             }
#             else
#             {
#                 return false;
#             }
#         });
#
#         $("#btnNext").click(function () {
#             if(fnValidateOnSearch())
#             {
#                 return true;
#             }
#             else
#             {
#                 return false;
#             }
#         });
#
#
#         $('#btnLast').click(function () {
#             if(fnValidateOnSearch())
#             {
#                 return true;
#             }
#             else
#             {
#                 return false;
#             }
#         });
#
#         $(document).on("click", "[data-pg]", function () {
#             var pgtraverse = $(this).attr("data-pg");
#             //BindGrid(pgtraverse);
#             $("#pageTraverse").val(pgtraverse);
#             $("#frmSearchList").submit();
#
#
#
#         });
#
#         $('#CompletionDate_From').datepicker({ changeMonth: true, changeYear: true,dateFormat: 'dd/mm/yy' ,minDate:0 });
#         $('#CompletionDate_To').datepicker({ changeMonth: true, changeYear: true,dateFormat: 'dd/mm/yy',minDate:0  });
#
#
#     });
#
# </script>
# <script>
#     function DivisionList(ID,ToBind,SelectedVal)
#     {
#         debugger;
#         $("#loader").show();
#         var DivID = $("#" + ID).val();
#         InnerDivision(DivID, ToBind, SelectedVal);
#         $("#District").empty();
#         $("#District").append($('<option></option>').val("").html("Select District"));
#         $("#Taluka").empty();
#         $("#Taluka").append($('<option></option>').val("").html("Select Taluka"));
#         $("#Village").empty();
#         $("#Village").append($('<option></option>').val("").html("Select Village"));
#         $("#loader").hide();
#     }
#     function InnerDivision(DivID, ToBind, SelectedVal) {
#
#         $.ajax
#        ({
#            url: '/SearchList/GetDivision',
#            type: 'POST',
#            datatype: 'application/json',
#            contentType: 'application/json',
#            data: JSON.stringify({
#                StateID: +DivID
#            }),
#            success: function (result) {
#                debugger;
#
#                $("#" + ToBind).html("");
#                $("#" + ToBind).append
#                    ($('<option></option>').val('').html('Select Division'))
#                $.each(result, function (i, Div) {
#                    if (SelectedVal == Div.ID) {
#                        $("#" + ToBind).append
#                              ($("<option selected='selected'></option>").val(Div.ID).html(Div.Text))
#                    }
#                    else {
#                        $("#" + ToBind).append($('<option></option>').val(Div.ID).html(Div.Text))
#                    }
#                })
#            },
#            error: function () {
#
#            },
#        });
#
#     }
#     function DistrictList(ID, ToBind, SelectedVal) {
#         $("#loader").show();
#         var DivID = $("#" + ID).val(); InnerDistrict(DivID, ToBind, SelectedVal);
#         $("#Taluka").empty();
#         $("#Taluka").append($('<option></option>').val("").html("Select Taluka"));
#         $("#Village").empty();
#         $("#Village").append($('<option></option>').val("").html("Select Village"));
#         $("#loader").hide();
#
#     }
#     function InnerDistrict(DivID, ToBind, SelectedVal) {
#
#         $.ajax
#        ({
#            url: '/SearchList/GetDistrict',
#            type: 'POST',
#            datatype: 'application/json',
#            contentType: 'application/json',
#            data: JSON.stringify({
#                DivID: +DivID
#            }),
#            success: function (result) {
#
#
#                $("#" + ToBind).html("");
#                $("#" + ToBind).append
#                    ($('<option></option>').val('').html('Select District'))
#                $.each(result, function (i, Dis) {
#                    if (SelectedVal == Dis.ID) {
#                        $("#" + ToBind).append
#                              ($("<option selected='selected'></option>").val(Dis.ID).html(Dis.Text))
#                    }
#                    else {
#                        $("#" + ToBind).append($('<option></option>').val(Dis.ID).html(Dis.Text))
#                    }
#                })
#            },
#            error: function () {
#
#            },
#        });
#
#     }
#     function TalukaList(ID, ToBind) {
#
#         $("#loader").show();
#         var DisID = $("#" + ID).val();
#         InnerTaluka(DisID, ToBind, '0');
#         $("#Village").empty();
#         $("#Village").append($('<option></option>').val("").html("Select Village"));
#         $("#loader").hide();
#
#     }
#     function InnerTaluka(DisID, ToBind, SelectedVal) {
#         $.ajax
#        ({
#            url: '/SearchList/GetTaluka',
#            type: 'POST',
#            datatype: 'application/json',
#            contentType: 'application/json',
#            data: JSON.stringify({
#                DisID: +DisID
#            }),
#            success: function (result) {
#                $("#" + ToBind).html("");
#                $("#" + ToBind).append
#                    ($('<option></option>').val('').html('Select Taluka'))
#                $.each(result, function (i, Taluka) {
#                    if (SelectedVal == Taluka.ID) {
#                        $("#" + ToBind).append
#                              ($("<option selected='selected'></option>").val(Taluka.ID).html(Taluka.Text))
#                    }
#                    else {
#                        $("#" + ToBind).append
#                        ($('<option></option>').val(Taluka.ID).html(Taluka.Text))
#                    }
#                })
#            },
#            error: function () {
#
#            },
#        });
#     }
#     function VillageList(ID, ToBind) {
#
#         $("#loader").show();
#         var TalukaID = $("#" + ID).val();
#         InnerVillage(TalukaID, ToBind, '0');
#         $("#loader").hide();
#
#     }
#     function InnerVillage(TalukaID, ToBind, SelectedVal) {
#
#         $.ajax
#        ({
#            url: '/SearchList/GetVillage',
#            type: 'POST',
#            datatype: 'application/json',
#            contentType: 'application/json',
#            data: JSON.stringify({
#                TalukaID: +TalukaID
#            }),
#            success: function (result) {
#                $("#" + ToBind).html("");
#                $("#" + ToBind).append
#                    ($('<option></option>').val('').html('Select Village'))
#                $.each(result, function (i, Village) {
#
#                    if (SelectedVal == Village.ID) {
#                        $("#" + ToBind).append
#                              ($("<option selected='selected'></option>").val(Village.ID).html(Village.Text))
#                    }
#                    else {
#                        $("#" + ToBind).append
#                           ($('<option></option>').val(Village.ID).html(Village.Text))
#                    }
#                })
#            },
#            error: function () {
#
#            },
#        });
#     }
#     function showFile(e) {
#         var id = $(e).attr("data-qstr");
#
#
#         //Arg = Arg.split('/');
#         $("#dvProgress").show();
#         $.ajax
#                ({
#                    url: '/SearchList/ShowCertificate',
#                    type: 'POST',
#                    datatype: 'application/json',
#                    contentType: 'application/json',
#                    data: '{"ID":"' + id + '"}',
#                    success: function (result) {
#                        $("#dvProgress").hide();
#                        $("#dvShowFile").dialog({
#                            modal: true,
#                            title: '',
#                            width: 900,
#                            height: 750,
#                            buttons: {
#                                Close: function () {
#                                    $(this).dialog('close');
#                                }
#                            },
#                            open: function () {
#                                var object = "<object data=\"data:{FileType};base64,{FileName}\" type=\"{FileType}\" title=\"pdf\" width=\"850px\" height=\"850px\">";
#                                object += "If you are unable to view file, you can download from <a href = \"{FileName}\">here</a>";
#                                object += " or download <a target = \"_blank\" href = \"http://get.adobe.com/reader/\">Adobe PDF Reader</a> to view the file.";
#                                object += "</object>";
#                                object = object.replace(/{FileName}/g, result);
#                                object = object.replace(/{FileType}/g, "application/pdf");
#                                $("#dvShowFile").html(object);
#                                //alert($("span[id=title]").attr("id"));
#                                //$("span[id=title]").hide();
#                            }
#                        });
#                    },
#                    error: function (e) {
#                        $("#dvProgress").hide();
#
#                    },
#                });
#     }
#     function showFileApplicationPreview(e) {
#         var id = $(e).attr("data-qstr");
#
#
#         //Arg = Arg.split('/');
#         $("#dvProgress").show();
#         $.ajax
#                ({
#                    url: '/SearchList/showFileApplicationPreview',
#                    type: 'POST',
#                    datatype: 'application/json',
#                    contentType: 'application/json',
#                    data: '{"ID":"' + id + '"}',
#                    success: function (result) {
#                        $("#dvProgress").hide();
#                        $("#dvShowFile").dialog({
#                            modal: true,
#                            title: '',
#                            width: 900,
#                            height: 750,
#                            buttons: {
#                                Close: function () {
#                                    $(this).dialog('close');
#                                }
#                            },
#                            open: function () {
#                                var object = "<object data=\"data:{FileType};base64,{FileName}\" type=\"{FileType}\" title=\"pdf\" width=\"850px\" height=\"850px\">";
#                                object += "If you are unable to view file, you can download from <a href = \"{FileName}\">here</a>";
#                                object += " or download <a target = \"_blank\" href = \"http://get.adobe.com/reader/\">Adobe PDF Reader</a> to view the file.";
#                                object += "</object>";
#                                object = object.replace(/{FileName}/g, result);
#                                object = object.replace(/{FileType}/g, "application/pdf");
#                                $("#dvShowFile").html(object);
#                                //alert($("span[id=title]").attr("id"));
#                                //$("span[id=title]").hide();
#                            }
#                        });
#                    },
#                    error: function (e) {
#                        $("#dvProgress").hide();
#
#                    },
#                });
#     }
#
#     function showExtensionFile(e) {
#         var id = $(e).attr("data-qstr");
#
#
#         //Arg = Arg.split('/');
#         $("#dvProgress").show();
#         $.ajax
#                ({
#                    url: '/SearchList/ShowExtensionCertificate',
#                    type: 'POST',
#                    datatype: 'application/json',
#                    contentType: 'application/json',
#                    data: '{"ID":"' + id + '"}',
#                    success: function (result) {
#                        $("#dvProgress").hide();
#                        $("#dvShowFile").dialog({
#                            modal: true,
#                            title: '',
#                            width: 900,
#                            height: 750,
#                            buttons: {
#                                Close: function () {
#                                    $(this).dialog('close');
#                                }
#                            },
#                            open: function () {
#                                var object = "<object data=\"data:{FileType};base64,{FileName}\" type=\"{FileType}\" title=\"pdf\" width=\"850px\" height=\"850px\">";
#                                object += "If you are unable to view file, you can download from <a href = \"{FileName}\">here</a>";
#                                object += " or download <a target = \"_blank\" href = \"http://get.adobe.com/reader/\">Adobe PDF Reader</a> to view the file.";
#                                object += "</object>";
#                                object = object.replace(/{FileName}/g, result);
#                                object = object.replace(/{FileType}/g, "application/pdf");
#                                $("#dvShowFile").html(object);
#                                //alert($("span[id=title]").attr("id"));
#                                //$("span[id=title]").hide();
#                            }
#                        });
#                    },
#                    error: function (e) {
#                        $("#dvProgress").hide();
#
#                    },
#                });
#     }
#
#     function direction_on_map(LATITUDE,LONGITUDE) {
#         debugger;
#         // window.open('https://www.pmccare.in/pmc_siteplan/get_direction.html?NAME=' + id_val, '_blank');
#         window.open('../GIS/get_direction.aspx?LAT=' + LATITUDE +'&LNG= '+ LONGITUDE.trim(), '_blank');
#     }
#
#     function view_on_map(id_val) {
#         debugger;
#         window.open('../GIS/view_map.aspx?ID=' + id_val, '_blank');
#     }
#
#     function loadmap() {
#         debugger;
#         //window.open('../GIS/map.aspx', '_blank');
#         window.open('../GIS/default.aspx', '_blank');
#     }
#
# </script>
# <form action="/SearchList/Search" id="frmSearchList" method="post"><input name="__RequestVerificationToken" type="hidden" value="2kg7eM9G6zngjiYUiJJMdQEP-9c_J-_shSYUKEWD3ZStyTla4f8AFBHhV49B2pdCeuKSCS6tr5gqA6YEkOIuLmR8PylfUoNsNxJF_XYX95g1"/> <div class="header-search">
# <img alt="rera logo" class="rera-inner-logo" src="/Images/rera logo.png"/>
# <span class="header-title">Maharashtra Real Estate Regulatory Authority</span>
# <div class="clearfix"></div>
# </div>
# <div class="x_panel">
# <div class="x_title">
# <h2>Search Project Details</h2>
# <div class="clearfix"></div>
# </div>
# <div class="x_content">
# <div class="row">
# <div class="form-group">
# <div class="col-md-3 col-sm-3">
# <label for="Type">Select User Type</label><span style="color: Red;">*</span>
# </div>
# <div class="col-md-7 col-sm-7">
# <input checked="checked" data-val="true" data-val-required="Required" id="Promoter" name="Type" onchange="Checkboxck('Promoter')" type="radio" value="Promoter"/>
# <label for="Promoter">Registered Projects</label>
# <input id="Agent" name="Type" onchange="Checkboxck('Agent')" type="radio" value="Agent"/>
# <label for="Agent">Registered Agents</label>
# <input data-val="true" data-val-number="The field ID must be a number." data-val-required="The ID field is required." id="ID" name="ID" type="hidden" value="0"/>
# <input data-val="true" data-val-number="The field pageTraverse must be a number." data-val-required="The pageTraverse field is required." id="pageTraverse" name="pageTraverse" type="hidden" value="1"/>
# <span class="field-validation-valid text-danger" data-valmsg-for="Type" data-valmsg-replace="true"></span>
# <script type="text/javascript">
#                             function Checkboxck(ID) {
#                                 var value = $('#' + ID).val();
#
#                                 if (value == "Promoter") {
#                                     $("#divProject").show();
#                                     $("#divPromoName").show();
#                                     $("#divTalVill").hide();
#                                     $("#divCerti").show();
#                                     $("#divDivision").hide();
#                                     $("#divDistrict").hide();
#                                     $("#divFromDate").hide();
#                                     $("#divToDate").hide();
#                                     //$("#CertiNo").rules("remove", "required");
#                                     $("#CertiNo").val("");
#                                     $("#gridview").html("");
#                                     $("#div_norecords").css("display","block");
#                                     $("#divProjectType").hide();
#                                     $("#divState").hide();
#                                     $("#divHideAdvanceSearchbtn").hide();
#                                     $("#divAdvanceSearchbtn").show();
#                                     $("#btnHideAdvance").hide();
#                                     $("#btnAdvance").show();
#                                     $("#divAgentName").hide();
#                                     $("#dProject").val('');
#                                     //$("#divSourceComplaintNo").hide();
#                                     //$("#divSourceComplaintName").hide();
#
#                                     $("#Agent_Name").val('');
#
#
#                                     $('#State').prop('selectedIndex',0);
#                                     $('#Division').prop('selectedIndex',0);
#                                     $('#District').prop('selectedIndex',0);
#                                     $('#Taluka').prop('selectedIndex',0);
#                                     $('#Village').prop('selectedIndex',0);
#                                     $('#PType').prop('selectedIndex',0);
#                                     // $("#Agent_Name").val("");
#
#                                 }
#                                 else  {
#                                     //$("#divPromoName").hide();
#                                     //$("#divDivision").hide();
#                                     //$("#divDistrict").hide();
#                                     //$("#divProject").hide();
#                                     //$("#divTalVill").hide();
#                                     //$("#divCerti").show();
#                                     //$("#divFromDate").hide();
#                                     //$("#divToDate").hide();
#                                     ////$("#divAdvanceSearchbtn").hide();
#                                     //$("#Project").val("");
#                                     ////$("#promoter_name").val("");
#                                     //$("#CertiNo").val("");
#                                     //$("#CompletionDate_From").val("");
#                                     //$("#CompletionDate_To").val("");
#                                     //// $("#CertiNo").rules("add", "required");
#                                     //$('#Division').prop('selectedIndex',0);
#                                     //$('#District').prop('selectedIndex',0);
#                                     //$('#Taluka').prop('selectedIndex',0);
#                                     //$('#Village').prop('selectedIndex',0);
#                                     //$("#gridview").html("");
#                                     //$("#div_norecords").css("display","block");
#                                     //$("#divProjectType").hide();
#                                     //$('#PType').prop('selectedIndex',0);
#                                     //$("#divState").hide();
#                                     ////$("#divHideAdvanceSearchbtn").hide();
#
#                                     $("#divProject").hide();
#                                     $("#divPromoName").show();
#                                     $("#divTalVill").hide();
#                                     $("#divCerti").show();
#                                     $("#divDivision").hide();
#                                     $("#divDistrict").hide();
#                                     $("#divFromDate").hide();
#                                     $("#divToDate").hide();
#                                     //$("#CertiNo").rules("remove", "required");
#                                     $("#CertiNo").val("");
#                                     $("#gridview").html("");
#                                     $("#div_norecords").css("display","block");
#                                     $("#divProjectType").hide();
#                                     $("#divState").hide();
#                                     $("#divHideAdvanceSearchbtn").hide();
#                                     $("#divAdvanceSearchbtn").show();
#                                     $("#btnHideAdvance").hide();
#                                     $("#btnAdvance").show();
#                                     $("#divPromoName").hide();
#                                     $("#divAgentName").show();
#                                     $("#promoter_name").val("");
#                                     $("#Agent_name").val("");
#                                     $("#Project").val('');
#
#
#                                     $('#State').prop('selectedIndex',0);
#                                     $('#Division').prop('selectedIndex',0);
#                                     $('#District').prop('selectedIndex',0);
#                                     $('#Taluka').prop('selectedIndex',0);
#                                     $('#Village').prop('selectedIndex',0);
#                                     $('#PType').prop('selectedIndex',0);
#                                     //$("#divSourceComplaintNo").hide();
#                                     //$("#divSourceComplaintName").hide();
#
#                                 }
#
#                                 if (value == "SourceComplaint")
#                                 {
#                                     $('#State').prop('selectedIndex',0);
#                                     $('#Division').prop('selectedIndex',0);
#                                     $('#District').prop('selectedIndex',0);
#                                     $('#Taluka').prop('selectedIndex',0);
#                                     $('#Village').prop('selectedIndex',0);
#                                     $('#PType').prop('selectedIndex',0);
#                                     $("#btnHideAdvance").show();
#                                     $("#divPromoName").hide();
#                                     //$("#divSourceComplaintNo").show();
#                                     //$("#divSourceComplaintName").show();
#                                     $("#divAgentName").hide();
#                                     $("#divCerti").hide();
#
#                                 }
#
#                             }
#
#                             function loadAdvanceOption() {
#                                 $("#divDistrict").show();
#                                 $("#divTalVill").show();
#
#
#                                 if($('#Promoter').is(':checked'))
#                                 {
#                                     $("#divFromDate").show();
#                                     $("#divToDate").show();
#                                     $("#divProjectType").show();
#                                     $("#divProject").show();
#                                     $("#divDistrict").show();
#                                     $("#divTalVill").show();
#
#                                     //$('#State').prop('selectedIndex',0);
#                                     //$('#Division').prop('selectedIndex',0);
#                                     //$('#District').prop('selectedIndex',0);
#                                     //$('#Taluka').prop('selectedIndex',0);
#                                     //$('#Village').prop('selectedIndex',0);
#                                     //$('#PType').prop('selectedIndex',0);
#
#                                 }
#                                 if($('#Agent').is(':checked'))
#                                 {
#                                     $("#divFromDate").hide();
#                                     $("#divToDate").hide();
#                                     $("#divProjectType").hide();
#                                     $("#divProject").hide();
#                                     // $("#Agent_name").val("");
#                                     $("#promoter_name").val("");
#                                     //$('#State').prop('selectedIndex',0);
#                                     //$('#Division').prop('selectedIndex',0);
#                                     //$('#District').prop('selectedIndex',0);
#                                     //$('#Taluka').prop('selectedIndex',0);
#                                     //$('#Village').prop('selectedIndex',0);
#                                     //$('#PType').prop('selectedIndex',0);
#
#                                 }
#
#                                 $("#divDivision").show();
#                                 $("#btnAdvance").hide();
#                                 $("#btnHideAdvance").show();
#                                 $("#divAdvanceSearchbtn").hide();
#                                 $("#divHideAdvanceSearchbtn").show();
#                                 $("#divState").show();
#
#
#
#
#                             }
#                             function HideAdvanceOption() {
#                                 $("#btnHideAdvance").hide();
#                                 $("#btnAdvance").show();
#                                 $("#divDistrict").hide();
#                                 // $("#divProject").hide();
#                                 $("#divTalVill").hide();
#                                 $("#divFromDate").hide();
#                                 $("#divToDate").hide();
#                                 $("#divDivision").hide();
#                                 $("#divProjectType").hide();
#                                 $("#divAdvanceSearchbtn").show();
#                                 $("#divHideAdvanceSearchbtn").hide();
#                                 $("#CompletionDate_From").val("");
#                                 $("#CompletionDate_To").val("");
#                                 $("#divState").hide();
#                                 //$('#Division').prop('selectedIndex',0);
#                                 //$('#District').prop('selectedIndex',0);
#                                 //$('#Taluka').prop('selectedIndex',0);
#                                 //$('#Village').prop('selectedIndex',0);
#                                 //$('#PType').prop('selectedIndex',0);
#
#                                 //$('#State').prop('selectedIndex',0);
#                             }
#
#                         </script>
# </div>
# <div class="col-md-2 col-sm-2">
# <input class="btn btn-sm btn-danger" id="btnmap" name="btnmap" onclick="loadmap()" type="button" value="View all projects on Map"/>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="row">
# <div class="form-group">
# <div id="divProject">
# <div class="col-md-3 col-sm-3">
# <label for="Project">Project Name</label>
# </div>
# <div class="col-md-3 col-sm-3">
# <input class="form-control" data-val="true" data-val-regex="special characters are not allowed." data-val-regex-pattern="([a-zA-Z0-9_ .&amp;'-]+)" id="Project" maxlength="100" name="Project" type="text" value=""/>
# <span class="field-validation-valid text-danger" data-valmsg-for="Project" data-valmsg-replace="true"></span>
# <input id="hdnProject" name="Project" type="hidden" value=""/>
# </div>
# </div>
# <div id="divPromoName">
# <div class="col-md-3 col-sm-3">
# <label for="Promoter">Promoter Name</label>
# </div>
# <div class="col-md-3 col-sm-3">
# <input class="form-control" data-val="true" data-val-regex="special characters are not allowed." data-val-regex-pattern="([a-zA-Z0-9_ .&amp;'-]+)" id="promoter_name" maxlength="50" name="Promoter" type="text" value=""/>
# <span class="field-validation-valid text-danger" data-valmsg-for="Promoter" data-valmsg-replace="true"></span>
# <input id="hdnPromoter" name="Promoter" type="hidden" value=""/>
# </div>
# </div>
# <div id="divAgentName">
# <div class="col-md-3 col-sm-3">
# <label for="AgentName">Agent Name</label>
# </div>
# <div class="col-md-3 col-sm-3">
# <input class="form-control" data-val="true" data-val-regex="special characters are not allowed." data-val-regex-pattern="([a-zA-Z0-9_ .&amp;'-]+)" id="Agent_name" maxlength="25" name="AgentName" type="text" value=""/>
# <span class="field-validation-valid text-danger" data-valmsg-for="AgentName" data-valmsg-replace="true"></span>
# <input id="hdnAgent" name="AgentName" type="hidden" value=""/>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="row">
# <div class="form-group" id="divCerti">
# <div class="col-md-3 col-sm-3">
# <label for="CertiNo">MahaRERA Project / Agent Registration Number</label>
# </div>
# <div class="col-md-3 col-sm-3">
# <input class="form-control" data-val="true" data-val-regex="special characters are not allowed." data-val-regex-pattern="([a-zA-Z0-9_ .&amp;'-]+)" id="CertiNo" maxlength="15" name="CertiNo" type="text" value=""/>
# <span class="field-validation-valid text-danger" data-valmsg-for="CertiNo" data-valmsg-replace="true"></span>
# <input id="hdnCertiNo" name="CertiNo" type="hidden" value=""/>
# </div><div class="clearfix"></div>
# </div>
# </div>
# <div class="row" id="divAdvanceThree">
# <div class="form-group" id="divState">
# <div class="col-md-3 col-sm-3">
# <label for="State">State/UT</label>
# </div>
# <div class="col-md-3 col-sm-3">
# ...
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_65743" onclick="view_on_map('REA52700017728')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_65743" onclick="direction_on_map('18.019197300000000','74.339685100000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">94</td><td class="grid-cell" data-name="Project">GURU PRAJAKTA</td><td class="grid-cell" data-name="Name">PRAJ DEVELOPERS</td><td class="grid-cell" data-name="lastModifiedDate">14/01/2019</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=yopcQPhMxMvcXtRPOe5Rem0y80rzIAvBJJJHaLqgjeNqJO8QgAvNX%2bsBuRWhi1IaDjGqcRTDpsxB5I1cRTT4XN8%2fxhEBZ5VAyrAO95lG%2bCrialMIrti0S%2fNJB%2bb6Xm2Oetzjz2ovTE1y%2bE5o%2fvCdf3uKlbTutvEMmuAFrA7e8KLQ8AWOwKAZaA%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM0OSZEaXZpc2lvbj01JlVzZXJJRD0xNDkzNCZSb2xlSUQ9MSZBcHBJRD0yNjg1OSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_26859" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM0OSZEaXZpc2lvbj01JlVzZXJJRD0xNDkzNCZSb2xlSUQ9MSZBcHBJRD0yNjg1OSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_26859" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_26859" onclick="view_on_map('REA52100007939')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_26859" onclick="direction_on_map('18.605837000000000','73.909996000000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">95</td><td class="grid-cell" data-name="Project">MAJESTIQUE CITY</td><td class="grid-cell" data-name="Name">MANISH DWARKADAS MAHESHWARI</td><td class="grid-cell" data-name="lastModifiedDate">20/02/2019</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=eRanDlQuMYfDNA4bLcc%2buSCNWeOgGT6XVVSzuhk4uUiBvkeDiBXiMCyNqSb4cbwnFUD24ZX1IXHkZTQrGVpJ7XFpdY%2fB7L1Ep%2b72SmPd8uLaFnvc%2fvcAt28kDRoPu7jyItgdzxPy%2bQOEGyjvckKn%2bmT%2fMebAXorIkDrbdy5X%2fWFMSmhQnx9WpQ%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM1NiZEaXZpc2lvbj01JlVzZXJJRD0xNDQ3MyZSb2xlSUQ9MSZBcHBJRD0xMTU4NSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_11585" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM1NiZEaXZpc2lvbj01JlVzZXJJRD0xNDQ3MyZSb2xlSUQ9MSZBcHBJRD0xMTU4NSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_11585" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_11585" onclick="view_on_map('REA52100003117')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_11585" onclick="direction_on_map('18.581746900000000','73.981705600000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">96</td><td class="grid-cell" data-name="Project">Irene</td><td class="grid-cell" data-name="Name">Colosseum Developers Pvt.Ltd.</td><td class="grid-cell" data-name="lastModifiedDate">07/01/2019</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=8TpkOuNrLq%2frZt7E0195G5SnPzTYjVItB59MkNfu5YTOEVFSei0b%2f1XB%2f6M0zELwU7cf33adnac7puOcTnb3XJwYeD82v3WUmi%2b%2bTJuzFY4sq%2b7CxwrPlk9llTWWnpmyrtjvs87L%2byaOolZ%2fxmUd1apTgclb1zdt2ToWUCR2TmFpsDrJZ4nDKg%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM1NyZEaXZpc2lvbj01JlVzZXJJRD0xMTk3MSZSb2xlSUQ9MSZBcHBJRD0xNTY4NyZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_15687" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM1NyZEaXZpc2lvbj01JlVzZXJJRD0xMTk3MSZSb2xlSUQ9MSZBcHBJRD0xNTY4NyZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_15687" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_15687" onclick="view_on_map('REA52100004104')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_15687" onclick="direction_on_map('18.501960600000000','73.933024200000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">97</td><td class="grid-cell" data-name="Project">AMAR WESTVIEW</td><td class="grid-cell" data-name="Name">INC DEVELOPERS</td><td class="grid-cell" data-name="lastModifiedDate">05/01/2019</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=CATX0hMr0Z5P4qP1O0B60OdoEpU6M9L5phNi%2fHReu6HjOs6szni%2fbnlCzaEXKyetuC3oqtI%2bMgFMQCN8z%2bOAWB085xizx5nYtIP52gLWtYcuqrukU9tqqLxPgQpK%2faJLjiyAr8HsjqnzqCAox%2fR4QOLxdTVN6aONbiYlkqOc%2bfINrO1sDsyvfQ%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM1OSZEaXZpc2lvbj01JlVzZXJJRD0xNTAzOCZSb2xlSUQ9MSZBcHBJRD0xMjc1OCZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_12758" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM1OSZEaXZpc2lvbj01JlVzZXJJRD0xNTAzOCZSb2xlSUQ9MSZBcHBJRD0xMjc1OCZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_12758" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_12758" onclick="view_on_map('REA52100003154')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_12758" onclick="direction_on_map('19.172080400000000','72.948255000000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">98</td><td class="grid-cell" data-name="Project">Star City</td><td class="grid-cell" data-name="Name">Rajmata Constructions</td><td class="grid-cell" data-name="lastModifiedDate">08/12/2018</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=HIqBdGeLsE%2bTmutjSbXIVJqw0GSff43zvwoW0oB4w1b49ZXEb1gXD2XwREplIx2RjDc4YoK3D%2bUMZvsqLv7YKRsUyDOwzFRglB3VzOGXg82DREDtjPL4QZepTTqzMYJzNNKn04rnI4pazvZA6d%2fBjl4qpuJ9DeUi8elGEf%2bI1n5tBNDCcKX24Q%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM2MCZEaXZpc2lvbj01JlVzZXJJRD0xNDYxOCZSb2xlSUQ9MSZBcHBJRD0yMzM2OCZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_23368" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM2MCZEaXZpc2lvbj01JlVzZXJJRD0xNDYxOCZSb2xlSUQ9MSZBcHBJRD0yMzM2OCZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_23368" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_23368" onclick="view_on_map('REA52100005564')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_23368" onclick="direction_on_map('18.623907900000000','73.812498400000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">99</td><td class="grid-cell" data-name="Project">Belmac Residences E</td><td class="grid-cell" data-name="Name">SUPREME HOLDINGS &amp; HOSPITALITY (INDIA) LIMITED</td><td class="grid-cell" data-name="lastModifiedDate">01/02/2019</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=BVqQlZBH84BoWr5F7xW87z%2bB2doUOCIH3BLNsTirZ5yhiLnGSv2TUlfcRDhyb4sGz4pwhp%2b8iH%2f5K%2fv%2fR6DAYG4sroISUdkcM6R0%2b%2fPYEcTcQdqRprb1%2b%2f8zBuDG%2b7wvFP%2ftd%2bws1UWnexb8ddomx%2f4%2byt93qiUbyg1QQRQckqTP6VolfIk5sQ%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM2MSZEaXZpc2lvbj01JlVzZXJJRD0xMjgzNSZSb2xlSUQ9MSZBcHBJRD0xMjAxMSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_12011" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM2MSZEaXZpc2lvbj01JlVzZXJJRD0xMjgzNSZSb2xlSUQ9MSZBcHBJRD0xMjAxMSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_12011" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_12011" onclick="view_on_map('REA52100002551')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_12011" onclick="direction_on_map('18.559668800000000','73.912642300000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# <tr class="grid-row ">
# <td class="grid-cell" data-name="Srno">100</td><td class="grid-cell" data-name="Project">ABHISHRI ENCLAVE</td><td class="grid-cell" data-name="Name">Abhishri Landmark</td><td class="grid-cell" data-name="lastModifiedDate">24/09/2018</td><td class="grid-cell" data-name=""><b>
# <a href="/PrintPreview/PrintPreview?q=8q37AvZj1q7bF7qHFip%2btbnJIg5z1yRvEopbtIlon%2bDNkQ20CU6p429lr1DezLeVg9Oq28IOc%2f1DeKvTddBnrTllfIU7b302ZdkuMTiGWTRtg91%2bymlgf30jbewx2uj4VgC%2b%2frMHf%2bG%2bXOKobUhrT%2bb7WyI1xqboqCFHaAn9fUDXacBKDCvwDw%3d%3d" target="_blank"> View</a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-info" data-qstr="UHJvamVjdElEPTM2MiZEaXZpc2lvbj01JlVzZXJJRD0xNTE0NCZSb2xlSUQ9MSZBcHBJRD04ODA5OSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_88099" onclick="return showFileApplicationPreview(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-success" data-qstr="UHJvamVjdElEPTM2MiZEaXZpc2lvbj01JlVzZXJJRD0xNTE0NCZSb2xlSUQ9MSZBcHBJRD04ODA5OSZBY3Rpb249U0VBUkNIJkNoYXJhY3RlckQ9MDQmRXh0QXBwSUQ9" id="btnShow_88099" onclick="return showFile(this);" title="View Certificate">
# <i aria-hidden="true" class="fa fa-certificate"></i>
# </a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <label>NA</label>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-danger" id="btnMap_88099" onclick="view_on_map('REA52700021934')" title="View on Map"><i aria-hidden="true" class="fa fa-map-marker"></i></a>
# </b>
# </td><td class="grid-cell" data-name=""><b>
# <a class="btn btn-md btn-warning" id="btnDirections_88099" onclick="direction_on_map('19.222074000000000','73.078895700000000')" title="View Directions"><i aria-hidden="true" class="fa fa-arrows"></i></a>
# </b>
# </td> </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $('#PageSize').blur(function () {
#             $("#btnRefresh").click();
#         });
#     });
# </script>
# <ul class="pagination clearfix col-sm-12 col-xs-12">
# <li class="col-md-4 col-sm-4 text-center">
# <label for="TotalRecords">Total Records:</label>
#     6432
#     <input id="TotalRecords" name="TotalRecords" type="hidden" value="6432"/>
# </li>
# <li class="col-md-3 col-sm-3 text-center">
# <label for="CurrentPage">Page:</label>
# 2
# <input id="CurrentPage" name="CurrentPage" type="hidden" value="2"/>
# <label for="TotalPages">of</label>
# 129
# </li>
# <li class="col-md-5 col-sm-5 text-center">
# <input id="TotalPages" name="TotalPages" type="hidden" value="129"/>
# <button class="btn btn-success " id="btnFirst" name="Command" type="submit" value="First">
#             First
#         </button>
# <button class="btn btn-success " id="btnPrevious" name="Command" type="submit" value="Previous">
#             Previous
#         </button>
# <button class="btn btn-success " id="btnNext" name="Command" type="submit" value="Next">
#             Next
#         </button>
# <button class="btn btn-success " id="btnLast" name="Command" type="submit" value="Last">
#             Last
#         </button>
# <button class="btn btn-success " id="btnRefresh" name="Command" style="display:none" type="submit" value="Refresh">
#             Refresh
#         </button>
# </li>
# <div class="clearfix">
# </div>
# </ul>
# </div>
# </div>
# <div id="div_norecords" style="display:none">
# <h4 style="font-size: 16px;">
# <label for="No_Records_Found">No Records Found</label>
# </h4>
# </div>
# </div>
# </div>
# <div class="loader" id="dvProgress"></div>
# </form>
# </div>
# </div>
# </section>
# <footer>
# <div class="container">
# <p>© This is the official Application of Maharashtra Real Estate Regulatory Authority, India. All Rights Reserved.</p>
# <img alt="MahaOnline Logo" class="MahaOnlineLogo" src="/Images/mahaonline.png">
# </img></div>
# </footer>
# <script type="text/javascript">
#         (function ($) {
#             $('body').on('hidden', '.modal', function () {
#                 $(this).removeData("modal");
#             });
#         })(jQuery);
#     </script>
# </body>
# </html>
# >

# %%
try:

    sr=doc.find("div",{"id":"DivBind"})
    if sr.find("label").get_text().strip()=="No Records Found":
        print("No Records Found")
    else:
        print("SEARCH RESULT")
        static_url="https://maharerait.mahaonline.gov.in"
        urls=[]
        #sr=doc.find("div",{"id":"DivBind"})
        tbody=sr.find("table").find("tbody")

        for row  in tbody.find_all("tr"):
            url=row.find_all("td")[4].find("a")['href']
            url=static_url+url
            urls.append(url)
except:
        print("Something went wrong.......")
# Out:
# SEARCH RESULT

# %%
urls[1]
# Out:
# 'https://maharerait.mahaonline.gov.in/PrintPreview/PrintPreview?q=uZyolPUGcr5wxJ3TZVn%2b%2fqDZIF4ozsyBcVAmqHYurgkBwLI5XwwNpXtTJp0Q4xDqVX78GTN6q5JSl5YImng%2ftmO%2bYh1u7aN1RKJBVwf507LZC7xSLcD3ekuKb0YjWC7Jmyv4hZ4KiERS9B4DpbScFXLA8RtoUsW%2fIv2auC3t5tI%3d'

# %% [markdown]
# # Final Looping different pages

# %%
dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}
print(dict)
del(dict['Name']); # remove entry with key 'Name'

print(dict)
dict.clear();     # remove all entries in dict
print(dict)
del(dict) ;        # delete entire dictionary
# Out:
# {'Name': 'Zara', 'Age': 7, 'Class': 'First'}
# {'Age': 7, 'Class': 'First'}
# {}
